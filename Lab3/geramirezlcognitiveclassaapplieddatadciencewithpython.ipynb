# %% [markdown]
#  **Gabriel Enrique Ramírez León**

# %% [markdown]
# # Lab 3: Certificados

# %% [markdown]
# Screenshot Curso: Python for Data Science
#   ![P101FDS.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Screenshot Curso: Data Analysis with Python
#
# ![DAWP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Screenshot Curso:
# Data Visualization with Python
#
# ![DTVP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Lab 3: Subir certificados en Linkedin

# %% [markdown]
# ### Linkedin: https://www.linkedin.com/in/gabriel-enrique-ramírez-león-5711551b6/

# %% [markdown]
# ScreenShot:
#
# ![geramirezlcognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)
