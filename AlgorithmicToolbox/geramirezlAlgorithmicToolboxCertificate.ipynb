# %% [markdown]
# ## Algorithmic Toolbox Certificate

# %% [markdown]
# ![AlgToolboxCertificate.png](data:image/png;base64,...)

# %% [markdown]
# ## Algorithmic Toolbox Certificate published in Linkedin
# link: https://www.linkedin.com/in/gabriel-enrique-ramírez-león-5711551b6/

# %% [markdown]
# ![AlgToolbox.png](data:image/png;base64,...)
